# %%
import pandas as pd
df = pd.read_csv('data.csv')
print(df.head())
# Out:
#    Age  Salary  Purchased
# 0   19   20000          0
# 1   26   19000          0
# 2   32  160000          1
# 3   45   55000          1
# 4   28   35000          0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 4))
plt.scatter(df['Age'], df['Purchased'], c=df['Purchased'], cmap='bwr', label='Purchased')
plt.xlabel('Age')
plt.ylabel('Purchased (0 = No, 1 = Yes)')
plt.title('Jahnavi Project')
plt.legend(['No Purchase', 'Purchase'])
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x = df[['Age']]
y = df['Purchased']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = LogisticRegression() 
model.fit(x_train, y_train)
new_age = [[29]]
prediction = model.predict(new_age)
probability = model.predict_proba(new_age)
print(f"Prediction for Age {new_age[0][0]}: {'Will purchase' if prediction[0] == 1 else 'Will not purchase'}")
print(f"Probability: {probability[0]}")
# Out:
# Prediction for Age 29: Will not purchase
# Probability: [0.73053106 0.26946894]
# C:\Users\pasha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\pasha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
